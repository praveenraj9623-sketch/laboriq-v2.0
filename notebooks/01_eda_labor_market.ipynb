# %% [markdown]
# # Labor Market Intelligence EDA
# Run the pipeline first, then use this notebook for quick exploration.

# %%
import pandas as pd
jobs = pd.read_csv('../reports/processed_job_postings.csv')
jobs.head()

# %%
jobs['role_label'].value_counts()
